# %%
# filename = './cifar10-l2t-modifiedReward-dgx1-batch-1-Adam-lr0.1_2018-01-30-13-24.log'
filename = 'cifar10-l2t_2018-01-29-18-54.log'
f = open(filename, 'r')

# %%
contents = f.readlines()

# %%
filtered = [l.split()[l.split().index('/') -1] for l in contents if 'at' in l.split()]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-13fe43705009> in <module>()
# ----> 1 filtered = [l.split()[l.split().index('/') -1] for l in contents if 'at' in l.split()]
#
# ValueError: '/' is not in list

# %%
filtered = [int(l.split()[7].split('/')[0]) for l in contents if 'at' in l.split()]

# %%
import matplotlib.pyplot as plt
import numpy
def movingaverage(interval, window_size):
    window = numpy.ones(int(window_size))/float(window_size)
    return numpy.convolve(interval, window, 'same')

# %%
plt.figure()
window = 
plt.plot(range(len(filtered)), filtered)
plt.show()
# Out:
#   File "<ipython-input-12-f20ca2034256>", line 2
#     window =
#              ^
# SyntaxError: invalid syntax

# %%
from __future__ import division
from pylab import plot, ylim, xlim, show, xlabel, ylabel, grid
from numpy import linspace, loadtxt, ones, convolve
import numpy as np
import numpy

def movingaverage(interval, window_size):
    window= numpy.ones(int(window_size))/float(window_size)
    return numpy.convolve(interval, window, 'same')

x = np.array(range(len(filtered))) #data[:,0]
y = np.array(filtered) #data[:,1]


plot(x,y,"k.")
y_av = movingaverage(y, 1)
x[0] = 0
y_av[0] = 600
plot(x, y_av,"r")
xlim(0,200)
xlabel("Iterations")
ylabel("#batches")
grid(True)
show()

# %%
filtered[1]
# Out:
# 584
